# %%
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Check the current working directory

import os

os.getcwd()
# Out:
# 'C:\\Users\\miked\\Desktop\\Documents\\Data Analysis Projects\\Retail Sales SQL Analysis'

# %%
# Set the working directory

os.chdir(r"C:\Users\miked\Desktop\Documents\Data Analysis Projects\Retail Sales SQL Analysis\dataset")

# %%
# Load the dataset

mydata = pd.read_csv(r"C:\Users\miked\Desktop\Documents\Data Analysis Projects\Retail Sales SQL Analysis\dataset\online_retail.csv",
                     encoding="latin1")

# %%
# Inspect the dataset structure

mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# Display the head of the dataset

mydata.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Rename columns for convenience

mydata = mydata.rename(columns={
    'InvoiceNo': 'order_id',
    'StockCode': 'product_code',
    'Description': 'product_name',
    'Quantity': 'quantity',
    'InvoiceDate': 'order_date',
    'UnitPrice': 'unit_price',
    'CustomerID': 'customer_id',
    'Country': 'country'
})

# %%
# Convert the date column to the datetime format

mydata['order_date'] = pd.to_datetime(mydata['order_date'])

# %%
# Convert the customer ID column to the integer format

mydata['customer_id'] = mydata['customer_id'].astype("Int64")

# %%
# Display rows with missing values

mydata[mydata.isna().any(axis=1)]
# Out:
#        order_id product_code                     product_name  quantity  \
# 622      536414        22139                              NaN        56
# 1443     536544        21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444     536544        21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445     536544        21786               POLKADOT RAIN HAT          4
# 1446     536544        21787            RAIN PONCHO RETROSPOT         2
# ...         ...          ...                              ...       ...
# 541536   581498       85099B          JUMBO BAG RED RETROSPOT         5
# 541537   581498       85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538   581498        85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539   581498        85174                S/4 CACTI CANDLES         1
# 541540   581498          DOT                   DOTCOM POSTAGE         1
#
#                 order_date  unit_price  customer_id         country
# 622    2010-12-01 11:52:00        0.00         <NA>  United Kingdom
# 1443   2010-12-01 14:32:00        2.51         <NA>  United Kingdom
# 1444   2010-12-01 14:32:00        2.51         <NA>  United Kingdom
# 1445   2010-12-01 14:32:00        0.85         <NA>  United Kingdom
# 1446   2010-12-01 14:32:00        1.66         <NA>  United Kingdom
# ...                    ...         ...          ...             ...
# 541536 2011-12-09 10:26:00        4.13         <NA>  United Kingdom
# 541537 2011-12-09 10:26:00        4.13         <NA>  United Kingdom
# 541538 2011-12-09 10:26:00        4.96         <NA>  United Kingdom
# 541539 2011-12-09 10:26:00       10.79         <NA>  United Kingdom
# 541540 2011-12-09 10:26:00     1714.17         <NA>  United Kingdom
#
# [135080 rows x 8 columns]

# %%
# Count missing values in each column

mydata.isna().sum()
# Out:
# order_id             0
# product_code         0
# product_name      1454
# quantity             0
# order_date           0
# unit_price           0
# customer_id     135080
# country              0
# dtype: int64

# %%
# Calculate missing value percentages per column to understand impact of removal

(mydata.isna().sum() / len(mydata) * 100).round(2)
# Out:
# order_id         0.00
# product_code     0.00
# product_name     0.27
# quantity         0.00
# order_date       0.00
# unit_price       0.00
# customer_id     24.93
# country          0.00
# dtype: float64

# %%
# Inspect rows with missing values in product name column

mydata[mydata['product_name'].isna()]
# Out:
#        order_id product_code product_name  quantity          order_date  \
# 622      536414        22139          NaN        56 2010-12-01 11:52:00
# 1970     536545        21134          NaN         1 2010-12-01 14:32:00
# 1971     536546        22145          NaN         1 2010-12-01 14:33:00
# 1972     536547        37509          NaN         1 2010-12-01 14:33:00
# 1987     536549       85226A          NaN         1 2010-12-01 14:34:00
# ...         ...          ...          ...       ...                 ...
# 535322   581199        84581          NaN        -2 2011-12-07 18:26:00
# 535326   581203        23406          NaN        15 2011-12-07 18:31:00
# 535332   581209        21620          NaN         6 2011-12-07 18:35:00
# 536981   581234        72817          NaN        27 2011-12-08 10:33:00
# 538554   581408        85175          NaN        20 2011-12-08 14:06:00
#
#         unit_price  customer_id         country
# 622            0.0         <NA>  United Kingdom
# 1970           0.0         <NA>  United Kingdom
# 1971           0.0         <NA>  United Kingdom
# 1972           0.0         <NA>  United Kingdom
# 1987           0.0         <NA>  United Kingdom
# ...            ...          ...             ...
# 535322         0.0         <NA>  United Kingdom
# 535326         0.0         <NA>  United Kingdom
# 535332         0.0         <NA>  United Kingdom
# 536981         0.0         <NA>  United Kingdom
# 538554         0.0         <NA>  United Kingdom
#
# [1454 rows x 8 columns]

# %%
# Drop missing values from product name column

mydata = mydata.dropna(subset=['product_name'])

# %%
# Count duplicate entries

mydata.duplicated().sum()
# Out:
# np.int64(5268)

# %%
# Inspect duplicate entries to verify whether they are duplicates

mydata[mydata.duplicated(keep=False)].head(20)
# Out:
#     order_id product_code                       product_name  quantity  \
# 485   536409        22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 489   536409        22866      HAND WARMER SCOTTY DOG DESIGN         1
# 494   536409        21866        UNION JACK FLAG LUGGAGE TAG         1
# 517   536409        21866        UNION JACK FLAG LUGGAGE TAG         1
# 521   536409        22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 527   536409        22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537   536409        22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539   536409        22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 548   536412        22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# 555   536412        22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# 556   536412        22273               FELTCRAFT DOLL MOLLY         1
# 565   536412        21448          12 DAISY PEGS IN WOOD BOX         2
# 569   536412        22749  FELTCRAFT PRINCESS CHARLOTTE DOLL         1
# 574   536412        22141     CHRISTMAS CRAFT TREE TOP ANGEL         1
# 578   536412        21448          12 DAISY PEGS IN WOOD BOX         1
# 587   536412        22273               FELTCRAFT DOLL MOLLY         1
# 589   536412        22749  FELTCRAFT PRINCESS CHARLOTTE DOLL         1
# 594   536412        22141     CHRISTMAS CRAFT TREE TOP ANGEL         1
# 597   536412        22569        FELTCRAFT CUSHION BUTTERFLY         2
# 598   536412        21448          12 DAISY PEGS IN WOOD BOX         1
#
#              order_date  unit_price  customer_id         country
# 485 2010-12-01 11:45:00        4.95        17908  United Kingdom
# 489 2010-12-01 11:45:00        2.10        17908  United Kingdom
# 494 2010-12-01 11:45:00        1.25        17908  United Kingdom
# 517 2010-12-01 11:45:00        1.25        17908  United Kingdom
# 521 2010-12-01 11:45:00        2.95        17908  United Kingdom
# 527 2010-12-01 11:45:00        2.10        17908  United Kingdom
# 537 2010-12-01 11:45:00        2.95        17908  United Kingdom
# 539 2010-12-01 11:45:00        4.95        17908  United Kingdom
# 548 2010-12-01 11:49:00        2.95        17920  United Kingdom
# 555 2010-12-01 11:49:00        2.95        17920  United Kingdom
# 556 2010-12-01 11:49:00        2.95        17920  United Kingdom
# 565 2010-12-01 11:49:00        1.65        17920  United Kingdom
# 569 2010-12-01 11:49:00        3.75        17920  United Kingdom
# 574 2010-12-01 11:49:00        2.10        17920  United Kingdom
# 578 2010-12-01 11:49:00        1.65        17920  United Kingdom
# 587 2010-12-01 11:49:00        2.95        17920  United Kingdom
# 589 2010-12-01 11:49:00        3.75        17920  United Kingdom
# 594 2010-12-01 11:49:00        2.10        17920  United Kingdom
# 597 2010-12-01 11:49:00        3.75        17920  United Kingdom
# 598 2010-12-01 11:49:00        1.65        17920  United Kingdom

# %%
# Remove duplicate entries

mydata = mydata.drop_duplicates()

# %%
# Count rows with 0 or negative quantity values

(mydata['quantity'] <= 0).sum()
# Out:
# np.int64(9725)

# %%
# Remove rows with invalid quantity values

negative_quantity = mydata[mydata['quantity'] <= 0]

mydata = mydata.drop(negative_quantity.index)

# %%
# Count rows with 0 or negative price values

(mydata['unit_price'] <= 0).sum()
# Out:
# np.int64(584)

# %%
# Remove rows with invalid price values

negative_price = mydata[mydata['unit_price'] <= 0]

mydata = mydata.drop(negative_price.index)

# %%
# Identify cancelled orders

mydata[mydata['order_id'].str.startswith('C', na=False)]
# Out:
# Empty DataFrame
# Columns: [order_id, product_code, product_name, quantity, order_date, unit_price, customer_id, country]
# Index: []

# %%
# Check for remaining alphabetic order IDs

mydata[mydata['order_id'].str.contains('[A-Za-z]', na=False)]
# Out:
# Empty DataFrame
# Columns: [order_id, product_code, product_name, quantity, order_date, unit_price, customer_id, country, year, month, revenue]
# Index: []

# %%
row_remove = mydata[mydata['order_id'].str.contains('[A-Za-z]', na=False)]

mydata = mydata.drop(row_remove.index)

# %%
# Create year column of out date column

mydata['year'] = mydata['order_date'].dt.year

# %%
# Create month column of out date column

mydata['month'] = mydata['order_date'].dt.month

# %%
# Create revenue column combining quantity and price

mydata['revenue'] = mydata['quantity'] * mydata['unit_price']

# %%
# Save the cleaned dataset as a csv file

mydata.to_csv("retail_sales_clean.csv", index=False)
